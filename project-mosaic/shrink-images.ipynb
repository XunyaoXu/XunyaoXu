# %% [markdown]
# # Shrink Images for Project Mosaic
#
# If you use have many large images, this notebook contains the code to shrink your images to allow the mosaic to run quicker!
#
# - Run both of the below cells to shrink all your images.
# - Make sure your file folder is correct in the variables below:

# %%
# What folder contains your tile images?
tileImageFolder = "tiles"

# What is the size of your final, smaller tile images?
# - Your image will be resized to `tileImageDimension` x `tileImageDimension`
tileImageDimension = 320

# What is the new folder for your smaller tile images?
smallTileImageFolder = f"{tileImageFolder}-small"

# %%
import DISCOVERY
from PIL import Image
import os

os.makedirs(smallTileImageFolder, exist_ok=True)

for fileName in os.listdir(tileImageFolder):
  fullPath = os.path.join(tileImageFolder, fileName)
  if os.path.isfile(fullPath) and DISCOVERY.isImageFile(fullPath):
    print(f"Shrinking {fullPath}...")
    image = Image.open(fullPath)
    width, height = image.size
    dimension = min(width, height)
    image = image.crop((0, 
    0, dimension, dimension))
    image = image.resize((tileImageDimension, tileImageDimension), resample=Image.Resampling.LANCZOS)
    image.save(os.path.join(smallTileImageFolder, fileName))

tada = "\N{PARTY POPPER}"
print()
print(f"{tada} SHRINK COMPLETE!")
print(f"- All image files in \"{tileImageFolder}\" are now {tileImageDimension}px x {tileImageDimension}px and saved in \"{smallTileImageFolder}\".")
print(f"- Use \"{smallTileImageFolder}\" as your tile image folder to run the mosaic creation much faster!")
# Out:
# Shrinking tiles/IMG_3509.jpg...
# Shrinking tiles/IMG_3535.jpg...
# Shrinking tiles/9ed154009q767eac98829a2596f35297.JPG...
# Shrinking tiles/IMG_3694.jpg...
# Shrinking tiles/IMG_4845.jpg...
# Shrinking tiles/IMG_4851.jpg...
# Shrinking tiles/IMG_3657.jpg...
# Shrinking tiles/68014307bkefd6f81ce7ce7e6aa24c3c.JPG...
# Shrinking tiles/IMG_4312.jpg...
# Shrinking tiles/IMG_3333.jpg...
# Shrinking tiles/IMG_3440.jpg...
# Shrinking tiles/1ccae6d6cv9f28938fa1d8b4abb70006 2.JPG...
# Shrinking tiles/IMG_3332.jpg...
# Shrinking tiles/IMG_3454.jpg...
# Shrinking tiles/IMG_4313.jpg...
# Shrinking tiles/IMG_3483.jpg...
# Shrinking tiles/IMG_3656.jpg...
# Shrinking tiles/d80f9835drb14e4e5435888987521c02.JPG...
# Shrinking tiles/IMG_4850.jpg...
# Shrinking tiles/IMG_3859.jpg...
# Shrinking tiles/IMG_4844.jpg...
# Shrinking tiles/6330de4e220a7bd22a158a81d1bfe6a7.JPG...
# Shrinking tiles/78005bf2ahc5ef5f6d83bfb9f5221d09.JPG...
# Shrinking tiles/IMG_3534.jpg...
# Shrinking tiles/IMG_3508.jpg...
# Shrinking tiles/IMG_2819.jpg...
# Shrinking tiles/b4a9fdcb0aa93495f68e6fd0e586014b.JPG...
# Shrinking tiles/IMG_3522.jpg...
# Shrinking tiles/IMG_3668.jpg...
# Shrinking tiles/9b84c811cvfbdcb345591fc59d267405.JPG...
# Shrinking tiles/IMG_4810.jpg...
# Shrinking tiles/015ae06ddmf49a8334d09acffd4f9a2e.JPG...
# Shrinking tiles/IMG_3372.jpg...
# Shrinking tiles/IMG_3373.jpg...
# Shrinking tiles/39d1adda4t3709da098f390e90c21440.JPG...
# Shrinking tiles/IMG_3367.jpg...
# Shrinking tiles/786ac5e37q2ce86656dbfe95b3964ebf.JPG...
# Shrinking tiles/IMG_3603.jpg...
# Shrinking tiles/IMG_4811.jpg...
# Shrinking tiles/IMG_4226.JPG...
# Shrinking tiles/IMG_3549.jpg...
# Shrinking tiles/IMG_3565.jpg...
# Shrinking tiles/IMG_4222.jpg...
# Shrinking tiles/IMG_4746.jpg...
# Shrinking tiles/IMG_4801.jpg...
# Shrinking tiles/1ccae6d6cv9f28938fa1d8b4abb70006.JPG...
# Shrinking tiles/ae99b1c3dt8a05c9275094264e5f8cc4.JPG...
# Shrinking tiles/IMG_3363.jpg...
# Shrinking tiles/IMG_3377.jpg...
# Shrinking tiles/96a888267de5b499faf16837f6aeb8ab.JPG...
# Shrinking tiles/IMG_3362.jpg...
# Shrinking tiles/IMG_4800.jpg...
# Shrinking tiles/IMG_4747.jpg...
# Shrinking tiles/e5091b3b1t345b00ab50713597451322.JPG...
# Shrinking tiles/dbb8056b3q6fb4c37d57f60bf9ae2409.JPG...
# Shrinking tiles/IMG_3558.jpg...
# Shrinking tiles/IMG_4237.jpg...
# Shrinking tiles/IMG_4551.jpg...
# Shrinking tiles/IMG_4223.jpg...
# Shrinking tiles/IMG_3564.jpg...
# Shrinking tiles/IMG_4553.jpg...
# Shrinking tiles/IMG_4235.jpg...
# Shrinking tiles/IMG_4547.jpg...
# Shrinking tiles/IMG_4745.JPG...
# Shrinking tiles/IMG_4802.jpg...
# Shrinking tiles/IMG_4816.jpg...
# Shrinking tiles/IMG_3823.jpg...
# Shrinking tiles/IMG_3604.jpg...
# Shrinking tiles/IMG_3360.jpg...
# Shrinking tiles/IMG_4368.jpg...
# Shrinking tiles/IMG_3361.jpg...
# Shrinking tiles/IMG_3375.jpg...
# Shrinking tiles/IMG_3605.jpg...
# Shrinking tiles/54e286a96df221329a0b590c8665259c.JPG...
# Shrinking tiles/IMG_4546.jpg...
# Shrinking tiles/IMG_4552.jpg...
# Shrinking tiles/76dbf859asf93c34f1bfbc2292f03f0b.JPG...
# Shrinking tiles/IMG_3514.jpg...
# Shrinking tiles/IMG_3931.jpg...
# Shrinking tiles/IMG_4643.jpg...
# Shrinking tiles/IMG_3886.jpg...
# Shrinking tiles/abf53fe49qc48c506d1f8bb22438d4b6.JPG...
# Shrinking tiles/IMG_2795.jpg...
# Shrinking tiles/dfad03c18v5fe4b2e67fc133061f803e.JPG...
# Shrinking tiles/IMG_3307.jpg...
# Shrinking tiles/IMG_3313.jpg...
# Shrinking tiles/bc023fced329f6e6c097975d0a93e330.JPG...
# Shrinking tiles/IMG_4736.jpg...
# Shrinking tiles/IMG_3930.jpg...
# Shrinking tiles/IMG_3924.jpg...
# Shrinking tiles/e808a6b1el9b514f0e8020e00fe2d94e.JPG...
# Shrinking tiles/IMG_4252.jpg...
# Shrinking tiles/IMG_2810.jpg...
# Shrinking tiles/IMG_2812.jpg...
# Shrinking tiles/IMG_4250.jpg...
# Shrinking tiles/IMG_3926.jpg...
# Shrinking tiles/IMG_4734.jpg...
# Shrinking tiles/IMG_3885.jpg...
# Shrinking tiles/IMG_4654.JPG...
# Shrinking tiles/4033e257cvb65835b697f381c62023a4.JPG...
# Shrinking tiles/IMG_2796.jpg...
# Shrinking tiles/IMG_3339.jpg...
# Shrinking tiles/IMG_3477.jpg...
# Shrinking tiles/IMG_3338.jpg...
# Shrinking tiles/IMG_3489.jpg...
# Shrinking tiles/IMG_2797.jpg...
# Shrinking tiles/IMG_3660.jpg...
# Shrinking tiles/IMG_4641.jpg...
# Shrinking tiles/0ee628845r9679731bfcb3e260de7043.JPG...
# Shrinking tiles/IMG_3933.jpg...
# Shrinking tiles/IMG_2813.jpg...
# Shrinking tiles/ef9cd4d60g8d1659696cf749e2c315bf.JPG...
# Shrinking tiles/IMG_3512.jpg...
# Shrinking tiles/271b56903u992749a04f601abffb8d90.JPG...
# Shrinking tiles/IMG_3880.jpg...
# Shrinking tiles/IMG_3894.jpg...
# Shrinking tiles/IMG_4645.jpg...
# Shrinking tiles/IMG_3499.jpg...
# Shrinking tiles/IMG_4309.jpg...
# Shrinking tiles/IMG_4335.jpg...
# Shrinking tiles/IMG_4334.jpg...
# Shrinking tiles/IMG_3315.jpg...
# Shrinking tiles/IMG_4485.jpg...
# Shrinking tiles/cbd38d152qdfcd8eb23ca134ad08fd08.JPG...
# Shrinking tiles/IMG_3895.jpg...
# Shrinking tiles/IMG_4644.jpg...
# Shrinking tiles/IMG_4650.JPG...
# Shrinking tiles/IMG_3665.jpg...
# Shrinking tiles/IMG_3856.JPG...
# Shrinking tiles/IMG_2814.jpg...
# Shrinking tiles/IMG_3511.jpg...
# Shrinking tiles/IMG_3539.jpg...
# Shrinking tiles/IMG_4849.jpg...
# Shrinking tiles/IMG_3897.jpg...
# Shrinking tiles/IMG_3316.jpg...
# Shrinking tiles/IMG_4848.jpg...
# Shrinking tiles/832405fcfcf4a062a1176878e30a5e99.JPG...
# Shrinking tiles/IMG_3538.jpg...
# Shrinking tiles/IMG_3510.jpg...
# Shrinking tiles/IMG_2815.jpg...
#
# 🎉 SHRINK COMPLETE!
# - All image files in "tiles" are now 320px x 320px and saved in "tiles-small".
# - Use "tiles-small" as your tile image folder to run the mosaic creation much faster!
